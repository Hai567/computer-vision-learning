# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>

# %% [markdown]
# # Image Basics Assessment
#
# ## Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
raw_image = cv2.imread("../DATA/dog_backpack.jpg")
plt.imshow(raw_image)

# %%
fixed_img = cv2.cvtColor(raw_image, cv2.COLOR_BGR2RGB)
plt.imshow(fixed_img)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
upsidedown_img = cv2.flip(fixed_img, 0)
plt.imshow(upsidedown_img)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
cp_img = fixed_img.copy()
cv2.rectangle(img=cp_img, pt1=(200, 400), pt2=(600, 750), color=(255, 0, 0), thickness=5)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 50,  40,  39],
#         [ 51,  39,  39],
#         [ 52,  38,  38],
#         ...,
#         [ 73,  80,  86],
#         [ 72,  77,  81],
#         [ 70,  75,  79]],
#
#        [[ 51,  41,  40],
#         [ 52,  40,  40],
#         [ 52,  38,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 52,  42,  40],
#         [ 51,  40,  38],
#         [ 53,  39,  39],
#         ...,
#         [ 78,  83,  89],
#         [ 71,  78,  84],
#         [ 67,  75,  78]]], dtype=uint8)

# %%
plt.imshow(cp_img)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
cp_img = fixed_img.copy()
vertices = np.array([ [400, 800], [200, 1000], [600, 1000] ])
pts = vertices.reshape(-1, 1, 2)
cv2.polylines(img=cp_img, pts=[pts], isClosed=True, color=(0, 0, 255), thickness=5)

plt.imshow(cp_img)

# %% [markdown]
# ### BONUS TASK. Can you figure our how to fill in this triangle? It requires a different function that we didn't show in the lecture! See if you can use google search to find it.
#
# [CLICK ME FOR A DIRECT LINK TO THE HINT](https://docs.opencv.org/3.0-beta/modules/imgproc/doc/drawing_functions.html#fillpoly)

# %%
cv2.fillPoly(cp_img, [pts], color=(0, 0, 255))
plt.imshow(cp_img)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
cp_img = fixed_img.copy()

def drawCir(event, x, y, flag, param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img=cp_img, center=(x, y), radius=50, thickness=4, color=(255, 0, 0))

cv2.namedWindow("Dog")
cv2.setMouseCallback("Dog", drawCir)

while True:
    cv2.imshow("Dog", cp_img)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()
